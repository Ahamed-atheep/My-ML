# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Users\ahame\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(data=np.arange(0,20).reshape(5,4),index=('row1','row2','row3','row4','row5'),columns=('col1','col2','col3','col4'))

# %%
df
# Out:
#       col1  col2  col3  col4
# row1     0     1     2     3
# row2     4     5     6     7
# row3     8     9    10    11
# row4    12    13    14    15
# row5    16    17    18    19

# %%
df.head()
# Out:
#       col1  col2  col3  col4
# row1     0     1     2     3
# row2     4     5     6     7
# row3     8     9    10    11
# row4    12    13    14    15
# row5    16    17    18    19

# %%
df.to_csv('test.csv')

# %%
##accesing the elements 
## i)loc
## ii)iloc

df.loc['row1']
# Out:
# col1    0
# col2    1
# col3    2
# col4    3
# Name: row1, dtype: int64

# %%
type(df.loc['row1'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[:,:]
# Out:
#       col1  col2  col3  col4
# row1     0     1     2     3
# row2     4     5     6     7
# row3     8     9    10    11
# row4    12    13    14    15
# row5    16    17    18    19

# %%
type(df.iloc[:,:])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[:,1:].values
# Out:
# array([[ 1,  2,  3],
#        [ 5,  6,  7],
#        [ 9, 10, 11],
#        [13, 14, 15],
#        [17, 18, 19]])

# %%
df.isnull().sum() ## checking if null is availble
# Out:
# col1    0
# col2    0
# col3    0
# col4    0
# dtype: int64

# %%
df['col1'].value_counts()
# Out:
# col1
# 0     1
# 4     1
# 8     1
# 12    1
# 16    1
# Name: count, dtype: int64

# %%
df['col1'].unique()
# Out:
# array([ 0,  4,  8, 12, 16])

# %%
df[['col1','col2']] ## accessing the multiple cols at a time
# Out:
#       col1  col2
# row1     0     1
# row2     4     5
# row3     8     9
# row4    12    13
# row5    16    17

# %%
## accessing the one col or one row is series
## accessing the atleast one row and one col is dataframe
